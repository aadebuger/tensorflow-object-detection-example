# %%
import cv2
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
im = Image.open('/home/aadebugergf/Ai/dataxgf/machinevision/data/belt_output2019062101/123.jpg')

# %%
plt.imshow(im)

# %%
im.thumbnail((480, 480))

# %%
plt.imshow(im)

# %%
im.size
# Out:
# (480, 360)
