# %%
# !ls ~/aixgf/tzimagedata/object*.jpg
# Out:
# /home/aadebugergf/aixgf/tzimagedata/object20190423160324.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423165541.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423165632.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423170928.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171417.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171419.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171421.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171527.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171529.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171532.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171559.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171601.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423171604.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423173205.jpg
# /home/aadebugergf/aixgf/tzimagedata/object20190423173207.jpg
# ...

# %%
from IPython.display import Image
Image(filename="/home/aadebugergf/aixgf/tzimagedata/object20190628161926.jpg")

# %%
from IPython.display import Image
Image(filename="/home/aadebugergf/aixgf/tzimagedata/object20190626114548.jpg")
